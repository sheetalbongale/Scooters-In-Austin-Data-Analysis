# %%
import csv

zip_dict = {}
with open("zip_tract_092019.csv", "r") as zip_data:
    zip_csv = csv.reader(zip_data)
    csv_header = next(zip_csv)
    for row in zip_csv:
        zip_dict[row[0]] = row[1]

zip_dict
# Out:
# {'00501': '36103158607',
#  '00601': '72001956700',
#  '00602': '72003430200',
#  '00603': '72005401302',
#  '00604': '72005400300',
#  '00605': '72005401301',
#  '00606': '72093960200',
#  '00610': '72011810200',
#  '00611': '72141957100',
#  '00612': '72013300102',
#  '00613': '72013300500',
#  '00614': '72013301200',
#  '00616': '72013300102',
#  '00617': '72017590200',
#  '00622': '72023830603',
#  '00623': '72023830604',
#  '00624': '72059740300',
#  '00627': '72027320401',
#  '00631': '72081958400',
#  '00637': '72121960400',
#  '00638': '72039955800',
#  '00641': '72141957100',
#  '00646': '72051540100',
#  '00647': '72121960700',
#  '00650': '72013300102',
#  '00652': '72013300101',
#  '00653': '72055961300',
#  '00656': '72059740200',
#  '00659': '72065310300',
#  '00660': '72067820100',
#  '00662': '72071410500',
#  '00664': '72073956200',
#  '00667': '72079850400',
#  '00669': '72081958100',
#  '00670': '72083959900',
#  '00674': '72091570100',
#  '00676': '72099420302',
# ...
