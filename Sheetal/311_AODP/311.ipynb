# %% [markdown]
# ## 311 Unified Data Analysis
#
# ### Data Source and API
#
# - AODP Dataset Access: https://data.austintexas.gov/City-Government/311-Unified-Data-Test-Site-2019/i26j-ai4z
# - API Endpoint: https://data.austintexas.gov/resource/i26j-ai4z.json
# - API Documentation: https://dev.socrata.com/foundry/data.austintexas.gov/i26j-ai4z

# %% [markdown]
# ### Data Extraction

# %%
# Dependencies and packages
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math as math
import datetime as dt
import seaborn as sns
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.austintexas.gov", None)

results = client.get("i26j-ai4z", limit=50000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
#df = pd.read_csv('Data_Files/311_Unified_Data_Test_Site_2019.csv', low_memory=False)
#df_backup = df

# %%
results_df.head()
# Out:
#      sr_number sr_type_code                        sr_type_desc  \
# 0  20-00011280     CODECOMP  Austin Code - Request Code Officer
# 1  20-00011277      ACLONAG                           Loose Dog
# 2  20-00011273     SBPOTREP                      Pothole Repair
# 3  20-00011249     STREETL2         Street Light Issue- Address
# 4  20-00011248     SWSRECYC                ARR Missed Recycling
#
#          sr_department_desc sr_method_received_desc sr_status_desc  \
# 0    Austin Code Department                     Web           Open
# 1    Animal Services Office                   Phone           Open
# 2              Public Works       Spot311 Interface           Open
# 3  Austin Energy Department                   Phone            New
# 4  Austin Resource Recovery                   Phone            New
#
#             sr_status_date          sr_created_date          sr_updated_date  \
# 0  2020-01-09T19:28:39.000  2020-01-09T19:28:39.000  2020-01-09T19:28:39.000
# 1  2020-01-09T19:23:15.000  2020-01-09T19:23:15.000  2020-01-09T19:23:15.000
# 2  2020-01-09T19:13:32.000  2020-01-09T19:13:32.000  2020-01-09T19:13:32.000
# 3  2020-01-09T18:43:09.000  2020-01-09T18:43:09.000  2020-01-09T18:43:09.000
# 4  2020-01-09T18:42:04.000  2020-01-09T18:42:04.000  2020-01-09T18:42:04.000
#
#                                      sr_location  ... sr_location_map_page  \
# 0        10604 SCHOOL HOUSE LN, AUSTIN, TX 78750  ...                 433L
# 1  COLINTON AVE & HARRIS BRANCH PKWY, AUSTIN, TX  ...                 498X
# 2     6114 W WILLIAM CANNON DR, AUSTIN, TX 78749  ...                 612X
# 3     MONTOPOLIS DR & E RIVERSIDE DR, AUSTIN, TX  ...                 646A
# 4              8016 TISDALE DR, AUSTIN, TX 78757  ...                 525M
#
#   sr_location_map_tile :@computed_region_8spj_utxs  \
# 0                 MF38                           6
# 1                 MQ31                           1
# 2                 MC19                           8
# 3                 ML18                           3
# 4                 MK29                           7
#
#   :@computed_region_jcrc_4uuy :@computed_region_q9nd_rr82  \
# 0                          39                           6
# 1                           2                           8
# 2                          38                           2
# 3                           8                           3
# 4                           3                           7
#
#   :@computed_region_m2th_e4b7 :@computed_region_rxpj_nzrk  \
# 0                         540                          28
# 1                         540                           5
# 2                         126                          53
# 3                         114                          55
# 4                         217                          16
#
#   :@computed_region_a3it_2a2z :@computed_region_e9j2_6w3z sr_closed_date
# 0                        3639                         NaN            NaN
# 1                        8030                         NaN            NaN
# 2                        3638                          11            NaN
# 3                        3256                          46            NaN
# 4                        3645                           9            NaN
#
# [5 rows x 31 columns]

# %%
results_df.tail()
# Out:
#          sr_number sr_type_code                       sr_type_desc  \
# 49995  19-00360245     WWREPORT                 Water Waste Report
# 49996  19-00360236     PRTRROWM                     Tree Issue ROW
# 49997  19-00360235     SWSYARDT  ARR Missed Yard Trimmings/Compost
# 49998  19-00360232     SWSRECYC               ARR Missed Recycling
# 49999  19-00360225      ACFOUND             Found Animal - Pick Up
#
#              sr_department_desc sr_method_received_desc sr_status_desc  \
# 49995              Austin Water       Spot311 Interface         Closed
# 49996              Public Works                   Phone           Open
# 49997  Austin Resource Recovery                   Phone         Closed
# 49998  Austin Resource Recovery                   Phone         Closed
# 49999    Animal Services Office                   Phone         Closed
#
#                 sr_status_date          sr_created_date  \
# 49995  2019-09-23T09:24:08.000  2019-09-19T14:00:10.000
# 49996  2019-09-19T15:00:13.000  2019-09-19T13:56:20.000
# 49997  2019-09-24T15:00:22.000  2019-09-19T13:56:17.000
# 49998  2019-09-21T10:23:57.000  2019-09-19T13:53:45.000
# 49999  2019-09-19T15:00:19.000  2019-09-19T13:49:17.000
#
#                sr_updated_date                              sr_location  ...  \
# 49995  2019-09-23T09:24:08.000  3318 SHOAL CREEK BLVD, AUSTIN, TX 78705  ...
# 49996  2019-09-20T23:00:05.000  1308 BRIANS MEADOW CV, AUSTIN, TX 78746  ...
# 49997  2019-09-24T15:00:22.000         9530 KETONA CV, AUSTIN, TX 78759  ...
# 49998  2019-09-21T10:23:57.000   1007 BIRD CREEK DR B, AUSTIN, TX 78758  ...
# 49999  2019-09-19T15:00:19.000   7905 SAN FELIPE BLVD, AUSTIN, TX 78729  ...
#
#       sr_location_map_page sr_location_map_tile :@computed_region_8spj_utxs  \
# 49995                 555S                 MJ25                          10
# 49996                 583U                 MF22                           8
# 49997                 494C                 MH33                          10
# 49998                 496X                 ML31                           4
# 49999                 434Y                 MH37                           6
#
#       :@computed_region_jcrc_4uuy :@computed_region_q9nd_rr82  \
# 49995                          43                           5
# 49996                          10                           2
# 49997                          51                           5
# 49998                          22                           9
# 49999                          30                           6
#
#       :@computed_region_m2th_e4b7 :@computed_region_rxpj_nzrk  \
# 49995                         217                          50
# 49996                         126                          29
# 49997                         540                          58
# 49998                         217                          18
# 49999                         540                          46
#
#       :@computed_region_a3it_2a2z :@computed_region_e9j2_6w3z  \
# 49995                        2858                          52
# 49996                        3260                         NaN
# 49997                        3647                         NaN
# 49998                        3646                          16
# 49999                        3245                         NaN
#
#                 sr_closed_date
# 49995  2019-09-23T09:24:08.000
# 49996                      NaN
# 49997  2019-09-24T15:00:22.000
# 49998  2019-09-21T10:23:57.000
# 49999  2019-09-19T15:00:19.000
#
# [5 rows x 31 columns]

# %%
results_df.describe()
# Out:
#           sr_number sr_type_code                        sr_type_desc  \
# count         50000        50000                               50000
# unique        50000          104                                 105
# top     19-00427889     CODECOMP  Austin Code - Request Code Officer
# freq              1         7239                                7239
#
#        sr_department_desc sr_method_received_desc sr_status_desc  \
# count               50000                   50000          50000
# unique                 13                      11             13
# top        Transportation                   Phone         Closed
# freq                12897                   38802          41110
#
#                  sr_status_date          sr_created_date  \
# count                     50000                    50000
# unique                    47944                    49777
# top     2019-11-13T13:53:54.000  2019-10-23T12:19:39.000
# freq                          9                        3
#
#                 sr_updated_date                           sr_location  ...  \
# count                     50000                                 49674  ...
# unique                    47147                                 31186  ...
# top     2019-11-13T23:00:05.000  1520 RUTHERFORD LN, AUSTIN, TX 78754  ...
# freq                         59                                   200  ...
#
#        sr_location_map_page sr_location_map_tile :@computed_region_8spj_utxs  \
# count                 49648                49544                       47264
# unique                 1731                  652                          10
# top                    585W                 MJ22                           9
# freq                   1087                 2560                        9901
#
#        :@computed_region_jcrc_4uuy :@computed_region_q9nd_rr82  \
# count                        49510                       47500
# unique                          54                          10
# top                              9                          10
# freq                          3951                        9901
#
#        :@computed_region_m2th_e4b7 :@computed_region_rxpj_nzrk  \
# count                        49590                       49652
# unique                          69                          61
# top                            217                          75
# freq                         18011                        3882
#
#        :@computed_region_a3it_2a2z :@computed_region_e9j2_6w3z  \
# count                        49652                       32396
# unique                          64                          94
# top                           2859                          60
# freq                          3957                        4003
#
#                  sr_closed_date
# count                     46555
# unique                    44618
# top     2019-11-13T13:53:54.000
# freq                          9
#
# [4 rows x 31 columns]

# %%
results_df.count()
# Out:
# sr_number                       50000
# sr_type_code                    50000
# sr_type_desc                    50000
# sr_department_desc              50000
# sr_method_received_desc         50000
# sr_status_desc                  50000
# sr_status_date                  50000
# sr_created_date                 50000
# sr_updated_date                 50000
# sr_location                     49674
# sr_location_street_number       40391
# sr_location_street_name         49674
# sr_location_city                49668
# sr_location_zip_code            49648
# sr_location_county              49617
# sr_location_x                   49674
# sr_location_y                   49674
# sr_location_lat                 49674
# sr_location_long                49674
# sr_location_lat_long            49674
# sr_location_council_district    47557
# sr_location_map_page            49648
# sr_location_map_tile            49544
# :@computed_region_8spj_utxs     47264
# :@computed_region_jcrc_4uuy     49510
# :@computed_region_q9nd_rr82     47500
# :@computed_region_m2th_e4b7     49590
# :@computed_region_rxpj_nzrk     49652
# :@computed_region_a3it_2a2z     49652
# :@computed_region_e9j2_6w3z     32396
# sr_closed_date                  46555
# dtype: int64

# %%
shared_mobility_calls = results_df[results_df["sr_type_desc"] == "Shared Micromobility"]
shared_mobility_calls
# Out:
#          sr_number sr_type_code          sr_type_desc sr_department_desc  \
# 36     20-00011131     DOCKMOBI  Shared Micromobility     Transportation
# 38     20-00011129     DOCKMOBI  Shared Micromobility     Transportation
# 41     20-00011124     DOCKMOBI  Shared Micromobility     Transportation
# 49     20-00011107     DOCKMOBI  Shared Micromobility     Transportation
# 80     20-00010999     DOCKMOBI  Shared Micromobility     Transportation
# ...            ...          ...                   ...                ...
# 49843  19-00360635     DOCKMOBI  Shared Micromobility     Transportation
# 49847  19-00360623     DOCKMOBI  Shared Micromobility     Transportation
# 49864  19-00360573     DOCKMOBI  Shared Micromobility     Transportation
# 49869  19-00360562     DOCKMOBI  Shared Micromobility     Transportation
# 49959  19-00360361     DOCKMOBI  Shared Micromobility     Transportation
#
#       sr_method_received_desc sr_status_desc           sr_status_date  \
# 36          Spot311 Interface           Open  2020-01-09T17:07:32.000
# 38          Spot311 Interface         Closed  2020-01-09T18:15:05.000
# 41          Spot311 Interface           Open  2020-01-09T17:04:27.000
# 49                      Phone         Closed  2020-01-09T18:18:11.000
# 80          Spot311 Interface           Open  2020-01-09T15:52:27.000
# ...                       ...            ...                      ...
# 49843       Spot311 Interface         Closed  2019-09-26T09:23:58.000
# 49847       Spot311 Interface         Closed  2019-09-26T09:24:25.000
# 49864       Spot311 Interface         Closed  2019-09-23T13:45:46.000
# 49869       Spot311 Interface         Closed  2019-09-23T13:46:42.000
# 49959                   Phone         Closed  2019-09-19T16:07:06.000
#
#                sr_created_date          sr_updated_date  \
# 36     2020-01-09T17:07:32.000  2020-01-09T17:07:32.000
# 38     2020-01-09T17:07:28.000  2020-01-09T18:15:05.000
# 41     2020-01-09T17:04:27.000  2020-01-09T17:04:27.000
# 49     2020-01-09T16:49:32.000  2020-01-09T18:18:10.000
# 80     2020-01-09T15:52:27.000  2020-01-09T15:52:27.000
# ...                        ...                      ...
# 49843  2019-09-19T17:24:05.000  2019-09-26T09:23:58.000
# 49847  2019-09-19T17:15:08.000  2019-09-26T09:24:25.000
# 49864  2019-09-19T16:42:01.000  2019-09-23T13:45:46.000
# 49869  2019-09-19T16:36:01.000  2019-09-23T13:46:42.000
# 49959  2019-09-19T14:56:48.000  2019-09-19T16:07:06.000
#
#                                     sr_location  ... sr_location_map_page  \
# 36                2 BRAZOS ST, AUSTIN, TX 78701  ...                 585W
# 38              71 TRINITY ST, AUSTIN, TX 78701  ...                 615A
# 41            80 RED RIVER ST, AUSTIN, TX 78701  ...                 615A
# 49               605 W 4TH ST, AUSTIN, TX 78701  ...                 585W
# 80              2309 MANOR RD, AUSTIN, TX 78722  ...                 585M
# ...                                         ...  ...                  ...
# 49843  2129 WILLIAM BARTON DR, AUSTIN, TX 78746  ...                 584Y
# 49847      712 AZIE MORTON RD, AUSTIN, TX 78704  ...                 584Y
# 49864     1920 S CONGRESS AVE, AUSTIN, TX 78704  ...                 614M
# 49869     1912 S CONGRESS AVE, AUSTIN, TX 78704  ...                 614M
# 49959       2026 GUADALUPE ST, AUSTIN, TX 78705  ...                 585J
#
#       sr_location_map_tile :@computed_region_8spj_utxs  \
# 36                    MJ22                           9
# 38                    MJ21                           9
# 41                    MJ21                           9
# 49                    MJ22                           9
# 80                    MK23                           1
# ...                    ...                         ...
# 49843                 MH22                           8
# 49847                 MH22                           5
# 49864                 MH20                           9
# 49869                 MH20                           9
# 49959                 MJ23                           9
#
#       :@computed_region_jcrc_4uuy :@computed_region_q9nd_rr82  \
# 36                             52                          10
# 38                             52                          10
# 41                             52                          10
# 49                             52                          10
# 80                             11                           8
# ...                           ...                         ...
# 49843                          10                           2
# 49847                           9                           1
# 49864                           9                          10
# 49869                           9                          10
# 49959                          43                          10
#
#       :@computed_region_m2th_e4b7 :@computed_region_rxpj_nzrk  \
# 36                            217                          24
# 38                            217                          24
# 41                            524                          24
# 49                            217                          24
# 80                            309                          74
# ...                           ...                         ...
# 49843                         217                          29
# 49847                         217                          75
# 49864                         217                          75
# 49869                         217                          75
# 49959                         217                          50
#
#       :@computed_region_a3it_2a2z :@computed_region_e9j2_6w3z  \
# 36                           2856                          60
# 38                           2856                          60
# 41                           2856                          60
# 49                           2856                          60
# 80                           2865                          75
# ...                           ...                         ...
# 49843                        3260                          93
# 49847                        2859                          93
# 49864                        2859                          42
# 49869                        2859                          42
# 49959                        2860                          44
#
#                 sr_closed_date
# 36                         NaN
# 38     2020-01-09T18:15:05.000
# 41                         NaN
# 49     2020-01-09T18:18:11.000
# 80                         NaN
# ...                        ...
# 49843  2019-09-26T09:23:58.000
# 49847  2019-09-26T09:24:25.000
# 49864  2019-09-23T13:45:46.000
# 49869  2019-09-23T13:46:42.000
# 49959  2019-09-19T16:07:06.000
#
# [2041 rows x 31 columns]

# %%
zipcodes = shared_mobility_calls["sr_location_zip_code"].value_counts()
zipcodes
# Out:
# 78701    754
# 78704    540
# 78702    164
# 78703    155
# 78705    142
# 78746     87
# 78741     39
# 78751     27
# 78723     21
# 78712     17
# 78756     15
# 78731      9
# 78664      9
# 78722      8
# 78754      7
# 78752      5
# 78747      5
# 78744      5
# 78721      5
# 78745      4
# 78757      4
# 78753      4
# 78758      4
# 78725      2
# 78748      2
# 78750      1
# 78681      1
# 78617      1
# 78736      1
# 78727      1
# 78660      1
# Name: sr_location_zip_code, dtype: int64

# %%
zp =
