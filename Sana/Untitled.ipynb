# %%
import requests
import json
url = "https://data.austintexas.gov/resource/i26j-ai4z.json"

#r = requests.get(url)

#read_file = r.json()

packages = json.dumps(read_file, indent=2)
#lat_long = packages["sr_location_lat_long"]["latitude"]["longitude"]
complaints = []
lat_long = []

for complaint in complaints:
        response = requests.get(url)
        complaints = (response)
        lat_long(response["sr_location_lat_long"]["latitude"])
        
lat_long
# Out:
# []

# %%
import pandas as pd 
from sodapy import Socrata

# %%
client = Socrata("data.austintexas.gov", None)
results = client.get("i26j-ai4z", limit=500000)
results_df = pd.DataFrame.from_records(results)


#results_df.sort_values("sr_type_code",ascending = False )

#results_df.sr_type_code.unique()

results_df.loc[results_df['sr_type_desc'] == "Shared Micromobility"]

#scooter_df
results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#           sr_number sr_type_code                         sr_type_desc  \
# 0       20-00011280     CODECOMP   Austin Code - Request Code Officer
# 1       20-00011277      ACLONAG                            Loose Dog
# 2       20-00011273     SBPOTREP                       Pothole Repair
# 3       20-00011249     STREETL2          Street Light Issue- Address
# 4       20-00011248     SWSRECYC                 ARR Missed Recycling
# ...             ...          ...                                  ...
# 499995  16-00242676     STREETL2          Street Light Issue- Address
# 499996  16-00242674     SWSYARDT  ARR Missed Yard Trimmings /Organics
# 499997  16-00242669      SBALLEY   Alley & Unpaved Street Maintenance
# 499998  16-00242666     PRTRROWM      Tree Issue ROW/Maintenance (PW)
# 499999  16-00242665     CODECOMP   Austin Code - Request Code Officer
#
# ...

# %%
scooter_df = pd.DataFrame({""
    
    
})
