# %% [markdown]
# ## Data Visualization

# %%
# Dependencies and packages
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math as math
import datetime as dt
import seaborn as sns
import pandas as pd
import geopandas as gpd
import plotly.figure_factory as ff

# %%
# Read the 311 data csv
csvpath = os.path.join("/Users/sheetalbongale/Scooters_In_Austin_Data_Analysis/resources/311data.csv")
df = pd.read_csv(csvpath, index_col=0, low_memory=False)
df.head()
# Out:
#        SR Number SR Type Code          SR Type Desc SR Department Desc  \
# 160  20-00013084     DOCKMOBI  Shared Micromobility     Transportation
# 293  20-00012691     DOCKMOBI  Shared Micromobility     Transportation
# 393  20-00012386     DOCKMOBI  Shared Micromobility     Transportation
# 759  20-00011403     DOCKMOBI  Shared Micromobility     Transportation
# 828  20-00011129     DOCKMOBI  Shared Micromobility     Transportation
#
#     SR Method Received Desc SR Status Desc           SR Status Date  \
# 160                   Phone         Closed  2020-01-11T13:45:35.000
# 293                   Phone         Closed  2020-01-11T09:53:05.000
# 393                   Phone         Closed  2020-01-11T09:58:46.000
# 759                   Phone         Closed  2020-01-11T10:03:28.000
# 828       Spot311 Interface         Closed  2020-01-09T18:15:05.000
#
#              SR Created Date          SR Updated Date  \
# 160  2020-01-11T12:42:11.000  2020-01-11T13:45:35.000
# 293  2020-01-10T21:56:11.000  2020-01-11T09:53:05.000
# 393  2020-01-10T16:08:38.000  2020-01-11T09:58:46.000
# 759  2020-01-09T23:14:43.000  2020-01-11T10:03:28.000
# 828  2020-01-09T17:07:28.000  2020-01-09T18:15:05.000
#
#                                SR Location  ...  SR Location County  \
# 160        2511 PEARL ST, AUSTIN, TX 78705  ...              TRAVIS
# 293    4001 GUADALUPE ST, AUSTIN, TX 78751  ...              TRAVIS
# 393        3313 KINGS LN, AUSTIN, TX 78705  ...              TRAVIS
# 759  1705 S CONGRESS AVE, AUSTIN, TX 78704  ...              TRAVIS
# 828        71 TRINITY ST, AUSTIN, TX 78701  ...              TRAVIS
#
#     SR Location X SR Location Y  SR Location Lat SR Location Long  \
# 160  3.112954e+06  1.007878e+07        30.290222       -97.746520
# 293  3.116137e+06  1.008440e+07        30.305450       -97.736021
# 393  3.114307e+06  1.008284e+07        30.301281       -97.741935
# 759  3.112036e+06  1.006302e+07        30.246961       -97.750586
# 828  3.114820e+06  1.006833e+07        30.261363       -97.741380
#
#                                   SR Location Lat Long  \
# 160  {'latitude': '30.29022193', 'longitude': '-97....
# 293  {'latitude': '30.30545021', 'longitude': '-97....
# 393  {'latitude': '30.30128133', 'longitude': '-97....
# 759  {'latitude': '30.24696112', 'longitude': '-97....
# 828  {'latitude': '30.26136334', 'longitude': '-97....
#
#      SR Location Council District  SR Location Map Page  SR Location Map Tile  \
# 160                             9                  585E                  MJ24
# 293                             9                  555T                  MJ25
# 393                             9                  555W                  MJ25
# 759                             9                  614M                  MH20
# 828                             9                  615A                  MJ21
#
#               SR Closed Date
# 160  2020-01-11T13:45:35.000
# 293  2020-01-11T09:53:05.000
# 393  2020-01-11T09:58:46.000
# 759  2020-01-11T10:03:28.000
# 828  2020-01-09T18:15:05.000
#
# [5 rows x 24 columns]

# %%
df.count()
# Out:
# SR Number                       8720
# SR Type Code                    8720
# SR Type Desc                    8720
# SR Department Desc              8720
# SR Method Received Desc         8720
# SR Status Desc                  8720
# SR Status Date                  8720
# SR Created Date                 8720
# SR Updated Date                 8720
# SR Location                     8720
# SR Location Street Number       8720
# SR Location Street Name         8720
# SR Location City                8720
# SR Location Zip Code            8720
# SR Location County              8720
# SR Location X                   8720
# SR Location Y                   8720
# SR Location Lat                 8720
# SR Location Long                8720
# SR Location Lat Long            8720
# SR Location Council District    8720
# SR Location Map Page            8720
# SR Location Map Tile            8720
# SR Closed Date                  8720
# dtype: int64
