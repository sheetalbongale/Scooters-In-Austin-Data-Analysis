# %%
import pandas as pd 
from sodapy import Socrata
import os
import csv

# %%
client = Socrata("data.austintexas.gov", None)
results = client.get("i26j-ai4z", limit=900000)
results_df = pd.DataFrame.from_records(results)


#results_df.sort_values("sr_type_code",ascending = False )

results_df.sr_type_code.unique() 

shared_mobility = results_df.loc[results_df['sr_type_desc'] == "Shared Micromobility"]

shared_mobility

shared_mobility
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#          sr_number sr_type_code          sr_type_desc sr_department_desc  \
# 36     20-00011131     DOCKMOBI  Shared Micromobility     Transportation
# 38     20-00011129     DOCKMOBI  Shared Micromobility     Transportation
# 41     20-00011124     DOCKMOBI  Shared Micromobility     Transportation
# 49     20-00011107     DOCKMOBI  Shared Micromobility     Transportation
# 80     20-00010999     DOCKMOBI  Shared Micromobility     Transportation
# ...            ...          ...                   ...                ...
# 79793  19-00281614     DOCKMOBI  Shared Micromobility     Transportation
# 79844  19-00281506     DOCKMOBI  Shared Micromobility     Transportation
# 80165  19-00280629     DOCKMOBI  Shared Micromobility     Transportation
# 80204  19-00280569     DOCKMOBI  Shared Micromobility     Transportation
# 80389  19-00280013     DOCKMOBI  Shared Micromobility     Transportation
#
#       sr_method_received_desc sr_status_desc           sr_status_date  \
# 36          Spot311 Interface           Open  2020-01-09T17:07:32.000
# 38          Spot311 Interface         Closed  2020-01-09T18:15:05.000
# 41          Spot311 Interface           Open  2020-01-09T17:04:27.000
# 49                      Phone         Closed  2020-01-09T18:18:11.000
# 80          Spot311 Interface           Open  2020-01-09T15:52:27.000
# ...                       ...            ...                      ...
# 79793       Spot311 Interface         Closed  2019-08-02T13:09:49.000
# 79844       Spot311 Interface         Closed  2019-07-31T09:45:28.000
# 80165       Spot311 Interface         Closed  2019-07-31T09:08:40.000
# 80204       Spot311 Interface         Closed  2019-07-31T09:10:05.000
# 80389       Spot311 Interface         Closed  2019-07-31T08:45:47.000
#
#                sr_created_date          sr_updated_date  \
# 36     2020-01-09T17:07:32.000  2020-01-09T17:07:32.000
# 38     2020-01-09T17:07:28.000  2020-01-09T18:15:05.000
# 41     2020-01-09T17:04:27.000  2020-01-09T17:04:27.000
# 49     2020-01-09T16:49:32.000  2020-01-09T18:18:10.000
# 80     2020-01-09T15:52:27.000  2020-01-09T15:52:27.000
# ...                        ...                      ...
# 79793  2019-07-24T20:23:08.000  2019-08-02T13:09:49.000
# 79844  2019-07-24T18:55:41.000  2019-07-31T09:45:28.000
# 80165  2019-07-24T10:18:53.000  2019-07-31T09:08:40.000
# 80204  2019-07-24T09:57:56.000  2019-07-31T09:10:05.000
# 80389  2019-07-23T18:20:14.000  2019-07-31T08:45:47.000
#
#                                     sr_location  ... sr_location_map_page  \
# 36                2 BRAZOS ST, AUSTIN, TX 78701  ...                 585W
# 38              71 TRINITY ST, AUSTIN, TX 78701  ...                 615A
# 41            80 RED RIVER ST, AUSTIN, TX 78701  ...                 615A
# 49               605 W 4TH ST, AUSTIN, TX 78701  ...                 585W
# 80              2309 MANOR RD, AUSTIN, TX 78722  ...                 585M
# ...                                         ...  ...                  ...
# 79793  115 SANDRA MURAIDA WAY, AUSTIN, TX 78703  ...                 584Z
# 79844            82 RAINEY ST, AUSTIN, TX 78701  ...                 615B
# 80165           404 W 26TH ST, AUSTIN, TX 78705  ...                 585E
# 80204           514 W 24TH ST, AUSTIN, TX 78705  ...                 585E
# 80389         92 CONGRESS AVE, AUSTIN, TX 78701  ...                 585W
#
#       sr_location_map_tile :@computed_region_8spj_utxs  \
# 36                    MJ22                           9
# 38                    MJ21                           9
# 41                    MJ21                           9
# 49                    MJ22                           9
# 80                    MK23                           1
# ...                    ...                         ...
# 79793                 MH22                           9
# 79844                 MJ21                           9
# 80165                 MJ24                           9
# 80204                 MJ24                           9
# 80389                 MJ22                           9
#
#       :@computed_region_jcrc_4uuy :@computed_region_q9nd_rr82  \
# 36                             52                          10
# 38                             52                          10
# 41                             52                          10
# 49                             52                          10
# 80                             11                           8
# ...                           ...                         ...
# 79793                          52                          10
# 79844                          52                          10
# 80165                          43                          10
# 80204                          43                          10
# 80389                          52                          10
#
#       :@computed_region_m2th_e4b7 :@computed_region_rxpj_nzrk  \
# 36                            217                          24
# 38                            217                          24
# 41                            524                          24
# 49                            217                          24
# 80                            309                          74
# ...                           ...                         ...
# 79793                         217                          69
# 79844                         502                          24
# 80165                         217                          50
# 80204                         217                          50
# 80389                         217                          24
#
#       :@computed_region_a3it_2a2z :@computed_region_e9j2_6w3z  \
# 36                           2856                          60
# 38                           2856                          60
# 41                           2856                          60
# 49                           2856                          60
# 80                           2865                          75
# ...                           ...                         ...
# 79793                        2856                          60
# 79844                        2856                          60
# 80165                        2860                          44
# 80204                        2860                          44
# 80389                        2856                          60
#
#                 sr_closed_date
# 36                         NaN
# 38     2020-01-09T18:15:05.000
# 41                         NaN
# 49     2020-01-09T18:18:11.000
# 80                         NaN
# ...                        ...
# 79793  2019-08-02T13:09:49.000
# 79844  2019-07-31T09:45:28.000
# 80165  2019-07-31T09:08:40.000
# 80204  2019-07-31T09:10:05.000
# 80389  2019-07-31T08:45:47.000
#
# [3588 rows x 31 columns]

# %%
scooter_df = pd.DataFrame({
    "complaint_number": shared_mobility["sr_number"],
    "complaint_type": shared_mobility["sr_type_desc"],
    "complaint_date": shared_mobility["sr_created_date"],
    "complaint_location": shared_mobility["sr_location"],
    "complaint_zip": shared_mobility["sr_location_zip_code"],
    "complaint_latitude": shared_mobility["sr_location_lat"],
    "complaint_longitudge": shared_mobility["sr_location_long"]
                                            })

scooter_df
# Out:
#       complaint_number        complaint_type           complaint_date  \
# 36         20-00011131  Shared Micromobility  2020-01-09T17:07:32.000
# 38         20-00011129  Shared Micromobility  2020-01-09T17:07:28.000
# 41         20-00011124  Shared Micromobility  2020-01-09T17:04:27.000
# 49         20-00011107  Shared Micromobility  2020-01-09T16:49:32.000
# 80         20-00010999  Shared Micromobility  2020-01-09T15:52:27.000
# ...                ...                   ...                      ...
# 79793      19-00281614  Shared Micromobility  2019-07-24T20:23:08.000
# 79844      19-00281506  Shared Micromobility  2019-07-24T18:55:41.000
# 80165      19-00280629  Shared Micromobility  2019-07-24T10:18:53.000
# 80204      19-00280569  Shared Micromobility  2019-07-24T09:57:56.000
# 80389      19-00280013  Shared Micromobility  2019-07-23T18:20:14.000
#
#                              complaint_location complaint_zip  \
# 36                2 BRAZOS ST, AUSTIN, TX 78701         78701
# 38              71 TRINITY ST, AUSTIN, TX 78701         78701
# 41            80 RED RIVER ST, AUSTIN, TX 78701         78701
# 49               605 W 4TH ST, AUSTIN, TX 78701         78701
# 80              2309 MANOR RD, AUSTIN, TX 78722         78722
# ...                                         ...           ...
# 79793  115 SANDRA MURAIDA WAY, AUSTIN, TX 78703         78703
# 79844            82 RAINEY ST, AUSTIN, TX 78701         78701
# 80165           404 W 26TH ST, AUSTIN, TX 78705         78705
# 80204           514 W 24TH ST, AUSTIN, TX 78705         78705
# 80389         92 CONGRESS AVE, AUSTIN, TX 78701         78701
#
#       complaint_latitude complaint_longitudge
# 36           30.26222912         -97.74362241
# 38           30.26136334         -97.74138045
# 41           30.26001066         -97.74003747
# 49           30.26781275         -97.74942505
# 80           30.28448413         -97.71758198
# ...                  ...                  ...
# 79793        30.26755559         -97.75494956
# 79844        30.25964236          -97.7385377
# 80165          30.290531         -97.74153837
# 80204        30.28795653         -97.74302556
# 80389        30.26267672         -97.74497865
#
# [3588 rows x 7 columns]

# %%
#scooter_df.complaint_zip.unique() 


scooter = scooter_df["complaint_zip"].value_counts()

scooter
# Out:
# 78701    1334
# 78704     852
# 78705     299
# 78702     294
# 78703     250
# 78746     223
# 78741      73
# 78751      47
# 78723      31
# 78756      29
# 78712      22
# 78731      13
# 78745      13
# 78664      11
# 78722      11
# 78752      10
# 78757      10
# 78754       9
# 78744       9
# 78721       7
# 78758       7
# 78747       6
# 78748       5
# 78681       4
# 78753       4
# 78717       3
# 78725       2
# 78759       2
# 78617       1
# 78727       1
# 78736       1
# 78613       1
# 78750       1
# 78660       1
# 78749       1
# Name: complaint_zip, dtype: int64

# %%
csvpath = os.path.join("ZIP_TRACT.csv")


zip_data = pd.read_csv(csvpath)

zip_data
# Out:
#           zip        tract  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0         501  36103158607   0.000000   1.000000   0.000000   1.000000
# 1         601  72113071700   0.188722   0.209068   0.125000   0.188301
# 2         601  72001956800   0.017797   0.025189   0.083333   0.020032
# 3         601  72001956300   0.004934   0.005038   0.005952   0.004968
# 4         601  72001956600   0.166520   0.347607   0.345238   0.182853
# ...       ...          ...        ...        ...        ...        ...
# 170188  99925   2198000200   0.000000   0.000000   1.000000   1.000000
# 170189  99926   2198940100   0.000000   0.000000   1.000000   1.000000
# 170190  99927   2198000100   0.000000   0.000000   1.000000   1.000000
# 170191  99928   2130000100   0.000000   0.000000   1.000000   1.000000
# 170192  99929   2275000300   0.000000   0.000000   1.000000   1.000000
#
# [170193 rows x 6 columns]

# %%
scooter_df.join = pd.merge(scooter_df,zip_data, on ="zip", how ='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2558c8f1d00> in <module>
# ----> 1 scooter_df.join = pd.merge(scooter_df,zip_data, on ="zip", how ='left')
#
# NameError: name 'pd' is not defined
